# %%
# for the count column
baseString = "= sumif( A2:A , \"<{}\", E2:E) - sum(H2:H{})~"
numBins = 50

for i in range(4,numBins+2):

  print(baseString.format( round((i-1) * (20/numBins), 2), i-1))

# %%
# for the bin value column
aString = "{},"
numBins = 50

for i in range(1,numBins+1):
  print(aString.format(i/2))
